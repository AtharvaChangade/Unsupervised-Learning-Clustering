# %% [markdown]
# ##### DATA SET DESCRIPTION :
#
#
# This dataset contains an airline passenger satisfaction survey.

# %% [markdown]
# * Gender: Gender of the passengers (Female, Male)
#
# * Customer Type: The customer type (Loyal customer, disloyal customer)
#
# * Age: The actual age of the passengers
#
# * Type of Travel: Purpose of the flight of the passengers (Personal Travel, Business Travel)
#
# * Class: Travel class in the plane of the passengers (Business, Eco, Eco Plus)
#
# * Flight distance: The flight distance of this journey
#
# * Inflight wifi service: Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
#
# * Departure/Arrival time convenient: Satisfaction level of Departure/Arrival time convenient
#
# * Ease of Online booking: Satisfaction level of online booking
#
# * Gate location: Satisfaction level of Gate location
#
# * Food and drink: Satisfaction level of Food and drink
#
# * Online boarding: Satisfaction level of online boarding
#
# * Seat comfort: Satisfaction level of Seat comfort
#
# *  Inflight entertainment: Satisfaction level of inflight entertainment
#
# * On-board service: Satisfaction level of On-board service
#
# * Leg room service: Satisfaction level of Leg room service
#
# * Baggage handling: Satisfaction level of baggage handling
#
# * Check-in service: Satisfaction level of Check-in service
#
# * Inflight service: Satisfaction level of inflight service
#
# * Cleanliness: Satisfaction level of Cleanliness

# %% [markdown]
# ### 1. Data Understanding (8 marks)
# #### a. Read the dataset (tab, csv, xls, txt, inbuilt dataset). Print the number of rows, cols and  types of variables? (1 mark)

# %%
df = pd.read_csv('data_set.csv')
df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Seat comfort  Inflight entertainment  \
# 0                       3  ...             5                       5
# 1                       3  ...             1                       1
# 2                       2  ...             5                       5
# 3                       5  ...             2                       2
# 4                       3  ...             5                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (1145, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1145 entries, 0 to 1144
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 1145 non-null   int64
#  1   Gender                             1145 non-null   object
#  2   Customer Type                      1145 non-null   object
#  3   Age                                1145 non-null   int64
#  4   Type of Travel                     1145 non-null   object
#  5   Class                              1145 non-null   object
#  6   Flight Distance                    1145 non-null   int64
#  7   Inflight wifi service              1145 non-null   int64
#  8   Departure/Arrival time convenient  1145 non-null   int64
#  9   Ease of Online booking             1145 non-null   int64
#  10  Gate location                      1145 non-null   int64
#  11  Food and drink                     1145 non-null   int64
#  12  Online boarding                    1145 non-null   int64
#  13  Seat comfort                       1145 non-null   int64
#  14  Inflight entertainment             1145 non-null   int64
#  15  On-board service                   1145 non-null   int64
#  16  Leg room service                   1145 non-null   int64
#  17  Baggage handling                   1145 non-null   int64
#  18  Checkin service                    1145 non-null   int64
#  19  Inflight service                   1145 non-null   int64
#  20  Cleanliness                        1145 non-null   int64
#  21  Departure Delay in Minutes         1145 non-null   int64
#  22  Arrival Delay in Minutes           1143 non-null   float64
# dtypes: float64(1), int64(18), object(4)
# memory usage: 205.9+ KB

# %%
df.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             2
# dtype: int64

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].median())

# %% [markdown]
# #### b Calculate five-point summary for numerical variables (1 MARK)

# %%
df.describe(exclude=object)
# Out:
#                   id          Age  Flight Distance  Inflight wifi service  \
# count    1145.000000  1145.000000      1145.000000            1145.000000
# mean    65317.478603    38.803493      1206.896070               2.734498
# std     37080.695046    15.256054      1016.733914               1.329233
# min       146.000000     7.000000        67.000000               0.000000
# 25%     33680.000000    26.000000       402.000000               2.000000
# 50%     64701.000000    40.000000       846.000000               3.000000
# 75%     96804.000000    50.000000      1773.000000               4.000000
# max    129860.000000    80.000000      4243.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                        1145.000000             1145.000000
# mean                            3.070742                2.761572
# std                             1.540613                1.408611
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding  Seat comfort  \
# count    1145.000000     1145.000000      1145.000000   1145.000000
# mean        2.946725        3.227074         3.237555      3.423581
# std         1.276383        1.355822         1.350791      1.351496
# min         1.000000        0.000000         0.000000      1.000000
# 25%         2.000000        2.000000         2.000000      2.000000
# 50%         3.000000        3.000000         3.000000      4.000000
# 75%         4.000000        4.000000         4.000000      5.000000
# max         5.000000        5.000000         5.000000      5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count             1145.000000       1145.000000       1145.000000
# mean                 3.367686          3.415721          3.297817
# std                  1.350409          1.260660          1.331912
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          3.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# count       1145.000000      1145.000000       1145.000000  1145.000000
# mean           3.613100         3.334498          3.649782     3.282096
# std            1.158581         1.226488          1.184310     1.312222
# min            1.000000         1.000000          0.000000     1.000000
# 25%            3.000000         3.000000          3.000000     2.000000
# 50%            4.000000         3.000000          4.000000     3.000000
# 75%            4.000000         4.000000          5.000000     4.000000
# max            5.000000         5.000000          5.000000     5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count                 1145.000000               1145.000000
# mean                    15.389520                 15.553712
# std                     34.609109                 34.222980
# min                      0.000000                  0.000000
# 25%                      0.000000                  0.000000
# 50%                      0.000000                  0.000000
# 75%                     15.000000                 15.000000
# max                    315.000000                307.000000

# %% [markdown]
# #### c. Is there any categorical feature present in this data ? Summarize observations for categorical variables – no. of categories, % observations in each category.  (2 MARK)

# %%
df.describe(include=object)
# Out:
#         Gender   Customer Type   Type of Travel     Class
# count     1145            1145             1145      1145
# unique       2               2                2         3
# top     Female  Loyal Customer  Business travel  Business
# freq       585             952              791       559

# %% [markdown]
# #### d. Generate the covariance and correlation tables for the data (2 MARK)

# %%
# a = pd.get_dummies(df['Class'], drop_first= True)

# %%
le = LabelEncoder()
df['Class'] = le.fit_transform(df['Class'])

# %%
df=df.drop('id', axis=1)

# %%
# df = pd.concat([a,df], axis=1)

# %%
df[['Gender', 'Customer Type', 'Type of Travel']] = pd.get_dummies(df[['Gender','Customer Type','Type of Travel']], 
                                                                   drop_first= True)

# %%
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       3              1  ...             5
# 1                       3              3  ...             1
# 2                       2              2  ...             5
# 3                       5              5  ...             2
# 4                       3              3  ...             5
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 4                 3
# 1                       1                 1                 5
# 2                       5                 4                 3
# 3                       2                 2                 5
# 4                       3                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
#
# [5 rows x 22 columns]

# %%
scalar = StandardScaler()
df_scaled = pd.DataFrame(scalar.fit_transform(df), columns=df.columns)

# %%
df_scaled.head()
# Out:
#      Gender  Customer Type       Age  Type of Travel     Class  \
# 0  1.022078      -0.450257 -1.692100        1.494812  2.255075
# 1  1.022078       2.220955 -0.905183       -0.668980 -0.936595
# 2 -0.978399      -0.450257 -0.839607       -0.668980 -0.936595
# 3 -0.978399      -0.450257 -0.905183       -0.668980 -0.936595
# 4  1.022078      -0.450257  1.455567       -0.668980 -0.936595
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0        -0.734924               0.199828                           0.603438
# 1        -0.956318               0.199828                          -0.695314
# 2        -0.063856              -0.552814                          -0.695314
# 3        -0.634559              -0.552814                           1.252814
# 4        -0.976981               0.199828                          -0.045938
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                0.169338      -1.525856  ...      1.166935
# 1                0.169338       0.041757  ...     -1.794041
# 2               -0.540891      -0.742049  ...      1.166935
# 3                1.589797       1.609370  ...     -1.053797
# 4                0.169338       0.041757  ...      1.166935
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                1.209284          0.463674         -0.223698
# 1               -1.754076         -1.917072          1.278558
# 2                1.209284          0.463674         -0.223698
# 3               -1.013236         -1.123490          1.278558
# 4               -0.272396         -0.329908          0.527430
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0          0.334088         0.542845          1.140587     1.309729
# 1         -0.529413        -1.904233          0.295844    -1.739869
# 2          0.334088         0.542845          0.295844     1.309729
# 3         -0.529413        -1.904233          0.295844    -0.977469
# 4          0.334088        -0.272847         -0.548898    -0.215070
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                    0.277808                  0.071512
# 1                   -0.415954                 -0.279283
# 2                   -0.444861                 -0.454680
# 3                   -0.126887                 -0.191584
# 4                   -0.444861                 -0.454680
#
# [5 rows x 22 columns]

# %%
cov_mat = np.cov(df_scaled)
cov_mat
# Out:
# array([[ 0.93212834, -0.36312135,  0.22884558, ..., -0.18117815,
#         -0.1557796 , -0.30007105],
#        [-0.36312135,  1.2195679 , -0.48996701, ..., -0.09810494,
#          0.29399066,  0.42131545],
#        [ 0.22884558, -0.48996701,  0.66375746, ...,  0.24229389,
#         -0.46924932, -0.47842132],
#        ...,
#        [-0.18117815, -0.09810494,  0.24229389, ...,  0.58351372,
#         -0.22661705,  0.05707698],
#        [-0.1557796 ,  0.29399066, -0.46924932, ..., -0.22661705,
#          1.20679679,  0.66376986],
#        [-0.30007105,  0.42131545, -0.47842132, ...,  0.05707698,
#          0.66376986,  1.00580773]])

# %%
df_scaled.corr()
# Out:
#                                      Gender  Customer Type       Age  \
# Gender                             1.000000      -0.011168 -0.009848
# Customer Type                     -0.011168       1.000000 -0.275844
# Age                               -0.009848      -0.275844  1.000000
# Type of Travel                    -0.023194      -0.281021 -0.043304
# Class                             -0.043673       0.002712 -0.077134
# Flight Distance                    0.029181      -0.237892  0.095284
# Inflight wifi service             -0.051703       0.005692  0.017038
# Departure/Arrival time convenient -0.013179      -0.194904  0.043585
# Ease of Online booking            -0.072567      -0.016542  0.022468
# Gate location                     -0.020769       0.027944 -0.002558
# Food and drink                    -0.022124      -0.028964  0.027431
# Online boarding                   -0.050505      -0.186344  0.198659
# Seat comfort                      -0.049411      -0.118729  0.208301
# Inflight entertainment             0.009185      -0.074255  0.062784
# On-board service                   0.000272      -0.022650  0.026613
# Leg room service                   0.025226      -0.018362  0.049644
# Baggage handling                   0.044753       0.055744 -0.078586
# Checkin service                    0.033749      -0.046733  0.048223
# Inflight service                   0.044457       0.038611 -0.066368
# Cleanliness                       -0.018613      -0.050592  0.063989
# Departure Delay in Minutes         0.056912      -0.032247 -0.032905
# Arrival Delay in Minutes           0.051428      -0.036613 -0.030659
#
#                                    Type of Travel     Class  Flight Distance  \
# Gender                                  -0.023194 -0.043673         0.029181
# Customer Type                           -0.281021  0.002712        -0.237892
# Age                                     -0.043304 -0.077134         0.095284
# Type of Travel                           1.000000  0.492287        -0.253506
# Class                                    0.492287  1.000000        -0.434297
# Flight Distance                         -0.253506 -0.434297         1.000000
# Inflight wifi service                   -0.116648 -0.018444        -0.003429
# Departure/Arrival time convenient        0.267472  0.122601        -0.018556
# Ease of Online booking                  -0.128307 -0.062141         0.021810
# Gate location                           -0.040201  0.026001         0.005908
# Food and drink                          -0.121851 -0.103453         0.048853
# Online boarding                         -0.242267 -0.294848         0.239292
# Seat comfort                            -0.153805 -0.180184         0.172128
# Inflight entertainment                  -0.207428 -0.194205         0.151677
# On-board service                        -0.055736 -0.197279         0.119164
# Leg room service                        -0.141133 -0.233593         0.131340
# Baggage handling                        -0.016380 -0.164884         0.081940
# Checkin service                          0.007072 -0.154366         0.081577
# Inflight service                        -0.028771 -0.138519         0.074983
# Cleanliness                             -0.133792 -0.135553         0.097184
# Departure Delay in Minutes               0.009074  0.041507        -0.017378
# Arrival Delay in Minutes                 0.014031  0.041513        -0.022547
#
#                                    Inflight wifi service  \
# Gender                                         -0.051703
# Customer Type                                   0.005692
# Age                                             0.017038
# Type of Travel                                 -0.116648
# Class                                          -0.018444
# Flight Distance                                -0.003429
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.297306
# Ease of Online booking                          0.715463
# Gate location                                   0.348187
# Food and drink                                  0.146494
# Online boarding                                 0.449944
# Seat comfort                                    0.118127
# Inflight entertainment                          0.238022
# On-board service                                0.139477
# Leg room service                                0.200229
# Baggage handling                                0.134740
# Checkin service                                 0.006267
# Inflight service                                0.128009
# Cleanliness                                     0.138696
# Departure Delay in Minutes                      0.039930
# Arrival Delay in Minutes                        0.030060
#
#                                    Departure/Arrival time convenient  \
# Gender                                                     -0.013179
# Customer Type                                              -0.194904
# Age                                                         0.043585
# Type of Travel                                              0.267472
# Class                                                       0.122601
# Flight Distance                                            -0.018556
# Inflight wifi service                                       0.297306
# Departure/Arrival time convenient                           1.000000
# Ease of Online booking                                      0.436358
# Gate location                                               0.486454
# Food and drink                                              0.002346
# Online boarding                                             0.025941
# Seat comfort                                                0.030097
# Inflight entertainment                                      0.033284
# On-board service                                            0.089711
# Leg room service                                            0.045529
# Baggage handling                                            0.102519
# Checkin service                                             0.122549
# Inflight service                                            0.112283
# Cleanliness                                                 0.030332
# Departure Delay in Minutes                                  0.003073
# Arrival Delay in Minutes                                    0.014476
#
#                                    Ease of Online booking  Gate location  ...  \
# Gender                                          -0.072567      -0.020769  ...
# Customer Type                                   -0.016542       0.027944  ...
# Age                                              0.022468      -0.002558  ...
# Type of Travel                                  -0.128307      -0.040201  ...
# Class                                           -0.062141       0.026001  ...
# Flight Distance                                  0.021810       0.005908  ...
# Inflight wifi service                            0.715463       0.348187  ...
# Departure/Arrival time convenient                0.436358       0.486454  ...
# Ease of Online booking                           1.000000       0.514120  ...
# Gate location                                    0.514120       1.000000  ...
# Food and drink                                   0.062243      -0.020785  ...
# Online boarding                                  0.377562       0.008361  ...
# Seat comfort                                     0.045750      -0.023392  ...
# Inflight entertainment                           0.093459       0.005796  ...
# On-board service                                 0.044544      -0.018275  ...
# Leg room service                                 0.159019       0.020139  ...
# Baggage handling                                 0.061262       0.064076  ...
# Checkin service                                  0.003197      -0.033277  ...
# Inflight service                                 0.057319      -0.014088  ...
# Cleanliness                                      0.031218       0.004806  ...
# Departure Delay in Minutes                       0.016968      -0.006060  ...
# Arrival Delay in Minutes                         0.016594      -0.006428  ...
#
#                                    Seat comfort  Inflight entertainment  \
# Gender                                -0.049411                0.009185
# Customer Type                         -0.118729               -0.074255
# Age                                    0.208301                0.062784
# Type of Travel                        -0.153805               -0.207428
# Class                                 -0.180184               -0.194205
# Flight Distance                        0.172128                0.151677
# Inflight wifi service                  0.118127                0.238022
# Departure/Arrival time convenient      0.030097                0.033284
# Ease of Online booking                 0.045750                0.093459
# Gate location                         -0.023392                0.005796
# Food and drink                         0.557600                0.628484
# Online boarding                        0.453339                0.324895
# Seat comfort                           1.000000                0.591351
# Inflight entertainment                 0.591351                1.000000
# On-board service                       0.118708                0.458515
# Leg room service                       0.098849                0.322030
# Baggage handling                       0.058419                0.374826
# Checkin service                        0.171266                0.110397
# Inflight service                       0.063272                0.434216
# Cleanliness                            0.688168                0.693188
# Departure Delay in Minutes            -0.013547               -0.018030
# Arrival Delay in Minutes              -0.016982               -0.021413
#
#                                    On-board service  Leg room service  \
# Gender                                     0.000272          0.025226
# Customer Type                             -0.022650         -0.018362
# Age                                        0.026613          0.049644
# Type of Travel                            -0.055736         -0.141133
# Class                                     -0.197279         -0.233593
# Flight Distance                            0.119164          0.131340
# Inflight wifi service                      0.139477          0.200229
# Departure/Arrival time convenient          0.089711          0.045529
# Ease of Online booking                     0.044544          0.159019
# Gate location                             -0.018275          0.020139
# Food and drink                             0.093544          0.034159
# Online boarding                            0.164737          0.134094
# Seat comfort                               0.118708          0.098849
# Inflight entertainment                     0.458515          0.322030
# On-board service                           1.000000          0.347362
# Leg room service                           0.347362          1.000000
# Baggage handling                           0.506412          0.407816
# Checkin service                            0.250323          0.157285
# Inflight service                           0.532026          0.369858
# Cleanliness                                0.156790          0.100931
# Departure Delay in Minutes                -0.036732         -0.013138
# Arrival Delay in Minutes                  -0.037879         -0.017467
#
#                                    Baggage handling  Checkin service  \
# Gender                                     0.044753         0.033749
# Customer Type                              0.055744        -0.046733
# Age                                       -0.078586         0.048223
# Type of Travel                            -0.016380         0.007072
# Class                                     -0.164884        -0.154366
# Flight Distance                            0.081940         0.081577
# Inflight wifi service                      0.134740         0.006267
# Departure/Arrival time convenient          0.102519         0.122549
# Ease of Online booking                     0.061262         0.003197
# Gate location                              0.064076        -0.033277
# Food and drink                             0.039284         0.067301
# Online boarding                            0.092851         0.179928
# Seat comfort                               0.058419         0.171266
# Inflight entertainment                     0.374826         0.110397
# On-board service                           0.506412         0.250323
# Leg room service                           0.407816         0.157285
# Baggage handling                           1.000000         0.224644
# Checkin service                            0.224644         1.000000
# Inflight service                           0.628050         0.246213
# Cleanliness                                0.092551         0.139561
# Departure Delay in Minutes                -0.014180         0.009366
# Arrival Delay in Minutes                  -0.022282         0.023281
#
#                                    Inflight service  Cleanliness  \
# Gender                                     0.044457    -0.018613
# Customer Type                              0.038611    -0.050592
# Age                                       -0.066368     0.063989
# Type of Travel                            -0.028771    -0.133792
# Class                                     -0.138519    -0.135553
# Flight Distance                            0.074983     0.097184
# Inflight wifi service                      0.128009     0.138696
# Departure/Arrival time convenient          0.112283     0.030332
# Ease of Online booking                     0.057319     0.031218
# Gate location                             -0.014088     0.004806
# Food and drink                             0.068079     0.665077
# Online boarding                            0.115981     0.351255
# Seat comfort                               0.063272     0.688168
# Inflight entertainment                     0.434216     0.693188
# On-board service                           0.532026     0.156790
# Leg room service                           0.369858     0.100931
# Baggage handling                           0.628050     0.092551
# Checkin service                            0.246213     0.139561
# Inflight service                           1.000000     0.122124
# Cleanliness                                0.122124     1.000000
# Departure Delay in Minutes                -0.094173     0.021850
# Arrival Delay in Minutes                  -0.090473     0.018066
#
#                                    Departure Delay in Minutes  \
# Gender                                               0.056912
# Customer Type                                       -0.032247
# Age                                                 -0.032905
# Type of Travel                                       0.009074
# Class                                                0.041507
# Flight Distance                                     -0.017378
# Inflight wifi service                                0.039930
# Departure/Arrival time convenient                    0.003073
# Ease of Online booking                               0.016968
# Gate location                                       -0.006060
# Food and drink                                       0.019834
# Online boarding                                     -0.031430
# Seat comfort                                        -0.013547
# Inflight entertainment                              -0.018030
# On-board service                                    -0.036732
# Leg room service                                    -0.013138
# Baggage handling                                    -0.014180
# Checkin service                                      0.009366
# Inflight service                                    -0.094173
# Cleanliness                                          0.021850
# Departure Delay in Minutes                           1.000000
# Arrival Delay in Minutes                             0.960107
#
#                                    Arrival Delay in Minutes
# Gender                                             0.051428
# Customer Type                                     -0.036613
# Age                                               -0.030659
# Type of Travel                                     0.014031
# Class                                              0.041513
# Flight Distance                                   -0.022547
# Inflight wifi service                              0.030060
# Departure/Arrival time convenient                  0.014476
# Ease of Online booking                             0.016594
# Gate location                                     -0.006428
# Food and drink                                     0.013169
# Online boarding                                   -0.036544
# Seat comfort                                      -0.016982
# Inflight entertainment                            -0.021413
# On-board service                                  -0.037879
# Leg room service                                  -0.017467
# Baggage handling                                  -0.022282
# Checkin service                                    0.023281
# Inflight service                                  -0.090473
# Cleanliness                                        0.018066
# Departure Delay in Minutes                         0.960107
# Arrival Delay in Minutes                           1.000000
#
# [22 rows x 22 columns]

# %% [markdown]
# ##### e. Create Visualization plots to find the relationship amongst the variables. (2 MARK)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df, annot=True)
plt.show()

# %% [markdown]
# ### 2a.  Will PCA can be applicable on this data ? (5 marks)
#
# ### 2b.  Print the top 5 eigen values and eigen vectors. Howmuch pecentage of varaiance in the data is explained by this top 5 principle components cummulatively ? (12 marks)

# %%
pca = PCA(n_components=5, random_state=10)
new_df = pca.fit_transform(df_scaled)

# %%
pca.explained_variance_
# Out:
# array([4.17384776, 2.39399077, 2.23175333, 1.95305923, 1.7331889 ])

# %%
pca.components_
# Out:
# array([[ 0.0057729 ,  0.05423636, -0.07469948,  0.1577104 ,  0.20780673,
#         -0.1575804 , -0.21852669, -0.08194233, -0.16879354, -0.06390668,
#         -0.28341031, -0.30095837, -0.3206478 , -0.40394486, -0.26495377,
#         -0.2280932 , -0.23734339, -0.15594945, -0.24954582, -0.32908353,
#          0.02309849,  0.0254548 ],
#        [ 0.04395204,  0.03275095,  0.02966795, -0.12604061, -0.14622613,
#          0.10198465, -0.41554408, -0.44248113, -0.49998935, -0.4499217 ,
#          0.16690111, -0.04989645,  0.18221284,  0.12881631, -0.00176138,
#         -0.05617032, -0.05910309,  0.02093595, -0.02891371,  0.18029206,
#         -0.05831064, -0.0599087 ],
#        [-0.0616082 , -0.13176447,  0.1435489 , -0.03276433,  0.07292947,
#         -0.00121346,  0.11105453,  0.0269899 ,  0.12236261,  0.07132816,
#          0.27998896,  0.18696551,  0.28336908,  0.02948447, -0.33560037,
#         -0.26693624, -0.40916894, -0.1387508 , -0.41649295,  0.26088866,
#          0.23751846,  0.23602023],
#        [ 0.11273845,  0.00867276, -0.10982428,  0.08100525,  0.05228775,
#         -0.05424454, -0.05427811, -0.01176469, -0.10182399, -0.08627789,
#         -0.01558938, -0.12185143, -0.06456368,  0.05202053,  0.13651164,
#          0.09982172,  0.18082072,  0.1060308 ,  0.12549839, -0.00175083,
#          0.64464816,  0.64512834],
#        [-0.05445254, -0.12384275, -0.04650569,  0.52553604,  0.485432  ,
#         -0.36017908, -0.09094594,  0.22003157, -0.15220819, -0.03190499,
#          0.2256341 , -0.17333804,  0.14355268,  0.18933195,  0.07395716,
#         -0.10208993,  0.07502961,  0.0469523 ,  0.12073095,  0.22716977,
#         -0.12406091, -0.11997306]])

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.18955466, 0.29827738, 0.39963212, 0.48833001, 0.56704252])

# %%
# 56.70% of varaiance in the data is explained by the top 5 principle components cummulatively

# %% [markdown]
# ### 3. Build the clustering model on PCA dimensions which are extracting 95 percentage of variance in the original data (25 Marks)

# %%
pca = PCA(0.95)
new_df = pca.fit_transform(df_scaled)

# %%
pca.explained_variance_
# Out:
# array([4.17384777, 2.39399099, 2.23175341, 1.95305931, 1.73318896,
#        1.52551917, 1.02468711, 0.9359151 , 0.92337934, 0.83423446,
#        0.67041782, 0.51561961, 0.48596851, 0.44401563, 0.43573418,
#        0.39776354, 0.32637182])

# %%
pca.components_
# Out:
# array([[ 0.00577257,  0.05423741, -0.07469853,  0.1577119 ,  0.20780228,
#         -0.15758102, -0.21852574, -0.08193792, -0.16879275, -0.06391178,
#         -0.28340598, -0.3009598 , -0.32065026, -0.40394565, -0.26495605,
#         -0.228093  , -0.23734016, -0.15595081, -0.24954775, -0.32908413,
#          0.02309838,  0.02545465],
#        [ 0.04395439,  0.03273944,  0.029662  , -0.12607344, -0.14617472,
#          0.10198863, -0.4155604 , -0.44251154, -0.49998997, -0.4498811 ,
#          0.16683569, -0.0498875 ,  0.18224875,  0.12882919, -0.00175297,
#         -0.05618088, -0.05915686,  0.02094743, -0.02885595,  0.18030511,
#         -0.05830839, -0.05990444],
#        [-0.06160748, -0.13177192,  0.14354694, -0.03277936,  0.07295013,
#         -0.00121171,  0.11106235,  0.0269723 ,  0.12235852,  0.071346  ,
#          0.27993455,  0.18695824,  0.28338753,  0.02949546, -0.33559845,
#         -0.26694734, -0.40919744, -0.13874289, -0.41646285,  0.26091303,
#          0.23751903,  0.23602187],
#        [ 0.11273664,  0.00867799, -0.10982165,  0.08102288,  0.05224608,
#         -0.05424997, -0.05426253, -0.01173482, -0.10181534, -0.086321  ,
#         -0.01554592, -0.12187356, -0.06456881,  0.05201444,  0.13649848,
#          0.09982432,  0.18085628,  0.10602023,  0.12546685, -0.00177262,
#          0.64464659,  0.64512583],
#        [-0.05445457, -0.12384296, -0.04650191,  0.52551332,  0.48542806,
#         -0.36018465, -0.09093867,  0.22006327, -0.1522109 , -0.03192878,
#          0.22560713, -0.17335541,  0.14357807,  0.18934547,  0.07392883,
#         -0.10210275,  0.07500207,  0.04694634,  0.12078438,  0.22716346,
#         -0.12405946, -0.11996937],
#        [-0.05613935,  0.63734096, -0.43660285, -0.27291124,  0.08351902,
#         -0.33285187,  0.14704739, -0.18598314,  0.09240411,  0.0864494 ,
#          0.19212667, -0.12058109, -0.0220777 ,  0.12219267, -0.06168806,
#         -0.03713823,  0.02461977, -0.21370438,  0.01806382,  0.12868193,
#         -0.00865936, -0.01613027],
#        [-0.73446884, -0.00904213,  0.1933993 ,  0.04439997,  0.13394159,
#         -0.21935736,  0.19363721, -0.26460117,  0.06442037, -0.33213739,
#         -0.11335554,  0.25797582, -0.02481124, -0.04846039,  0.11346156,
#          0.12720562,  0.00832464, -0.03567999,  0.03108956, -0.11773336,
#          0.05231602,  0.05234405],
#        [ 0.52674446, -0.1278178 ,  0.31472476,  0.00129056,  0.18551565,
#         -0.2050679 ,  0.22709342, -0.23354102,  0.06229047, -0.19154388,
#         -0.02146273,  0.09148075, -0.07824965,  0.12277173,  0.01955389,
#          0.23910004,  0.02024399, -0.53713541,  0.04153018, -0.07020991,
#         -0.01104566, -0.0268649 ],
#        [ 0.3665553 ,  0.22260959,  0.1468137 , -0.02298092,  0.05649552,
#         -0.36924742,  0.1255995 , -0.07255299,  0.06582756, -0.18431015,
#         -0.06505262,  0.28788818,  0.0599479 , -0.18485246, -0.05204303,
#         -0.08994997, -0.08169503,  0.67018585, -0.02844839, -0.02828438,
#         -0.03542048, -0.02755988],
#        [-0.12127989,  0.2572828 ,  0.68293879, -0.2285098 , -0.02980733,
#         -0.23554977, -0.22670497,  0.1234274 , -0.09743379,  0.33043927,
#         -0.03289758, -0.3337133 ,  0.09420864,  0.04203835,  0.04360995,
#          0.16481476,  0.01479195,  0.02557476, -0.04841157,  0.03492019,
#          0.029619  ,  0.03634873],
#        [ 0.02731876,  0.07453103,  0.20706693, -0.09632871,  0.01628441,
#          0.03476998,  0.01785642, -0.01212593, -0.02933085,  0.05797411,
#         -0.04360526,  0.15044275, -0.06311022,  0.04340669,  0.35362645,
#         -0.82326698,  0.12080866, -0.16627294,  0.22841078, -0.07437388,
#          0.03360603,  0.03295676],
#        [ 0.01595241, -0.20057077, -0.11297374, -0.08530179, -0.27733311,
#         -0.28441386,  0.02978447,  0.11901941,  0.05785325, -0.10596677,
#          0.17710069, -0.17494532, -0.2490747 ,  0.09581313,  0.5955286 ,
#          0.03381639, -0.44725169,  0.04269016, -0.24383005, -0.03130013,
#         -0.02451314, -0.01291869],
#        [ 0.04707556,  0.27277273,  0.05533791, -0.01246686,  0.55871517,
#          0.54183967,  0.16027918, -0.10534886, -0.0147307 ,  0.00337007,
#         -0.09596285, -0.11441787,  0.03277327,  0.06677892,  0.34636714,
#          0.10145572, -0.27468823,  0.13909434, -0.15447315,  0.01918425,
#         -0.00702995, -0.01465047],
#        [ 0.06034704,  0.35805071, -0.0754167 ,  0.27462547, -0.21516067,
#         -0.03351957, -0.1060458 ,  0.34411606, -0.08593464, -0.15711334,
#         -0.36178213,  0.24630396,  0.3983889 , -0.14850914,  0.24299489,
#          0.08642371, -0.01083021, -0.29621602, -0.20943906,  0.0825717 ,
#          0.01730216,  0.01492931],
#        [-0.02243204,  0.2907747 ,  0.20417912,  0.06402429, -0.11792307,
#          0.20651638,  0.10815576,  0.42913697,  0.11471965, -0.52220378,
#          0.3074148 , -0.17659147, -0.17453732, -0.01338329, -0.22124805,
#         -0.02440585, -0.16595061, -0.04472429,  0.29732138, -0.0821375 ,
#          0.00570096,  0.01714995],
#        [-0.01570067, -0.21197565, -0.16783294, -0.48850627,  0.25250659,
#         -0.13324717, -0.15647855,  0.26750908, -0.0305273 , -0.09939106,
#         -0.38129379,  0.05578193,  0.17606034,  0.10393205, -0.08839419,
#          0.0299426 , -0.35710966, -0.03496563,  0.40942899,  0.0589789 ,
#          0.0037728 ,  0.02759496],
#        [ 0.003199  ,  0.13248059,  0.05054321,  0.42530685, -0.23508266,
#          0.01548609, -0.03292211, -0.32350896,  0.02352759,  0.31113772,
#         -0.07945759,  0.0721772 , -0.05791209, -0.00912853, -0.02215713,
#          0.06149923, -0.51036054, -0.02139677,  0.48599769,  0.14802788,
#          0.02637181,  0.03783958]])

# %%
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.18955466, 0.29827739, 0.39963213, 0.48833002, 0.56704254,
#        0.63632376, 0.68285976, 0.7253642 , 0.76729934, 0.80518597,
#        0.83563289, 0.85904968, 0.88111986, 0.90128476, 0.92107356,
#        0.93913793, 0.95396006])

# %%
df_pca = pd.DataFrame(new_df, columns=[['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13',
                                       'PC14','PC15','PC16','PC17']])
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.219779  0.420280  0.161536  1.186096  3.583350  0.672398 -0.521641
# 1  2.950027 -0.840933 -1.515708 -0.609081 -2.554387  2.138962 -0.214763
# 2 -2.329654  2.079524  0.427731 -0.542633  0.384186  0.466972  0.624089
# 3  1.432704 -2.443888 -0.464587 -0.717783 -1.272743  0.585969 -0.191256
# 4 -1.046943  0.212116  0.761675 -0.996764 -0.630342 -0.559103 -0.098364
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0  0.475804  0.625970 -1.942639 -0.217646 -0.093702  0.616746 -0.037597
# 1  1.572498  0.218732 -0.055444 -1.190382 -0.737806 -1.050260  0.787866
# 2 -0.981587 -0.061489 -0.841733  0.140871  0.327152 -0.819810 -0.060434
# 3 -0.137589 -2.088605  0.611552 -1.342402  0.387421 -1.666388  0.079376
# 4  1.403242  1.111759  0.815486 -0.205865 -0.083753 -1.288013  0.528981
#
#        PC15      PC16      PC17
# 0  0.546347  0.760945 -0.363409
# 1  0.681185  0.247451  0.942457
# 2 -0.513705  0.244610 -0.156799
# 3  0.098201  1.104952  0.447357
# 4 -0.385479 -0.281254 -0.505680

# %% [markdown]
# #### a. Find the optimal K Value. (6 marks)

# %%
from sklearn.metrics import silhouette_score, silhouette_samples
import warnings
warnings.filterwarnings('ignore')
from yellowbrick.cluster import silhouette_visualizer

# %%
wcss=[]
for i in range(1,11):
    kmeans= KMeans(n_clusters=i, random_state=10)
    kmeans.fit(df_pca)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1,11),wcss)
plt.xticks(np.arange(1,11,1))
plt.title('Elbow plot')
plt.xlabel('Number of cluster')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
n_clusters=[2,3,4,5,6]
silhouette=[]
for K in n_clusters:
    cluster = KMeans(n_clusters=K, random_state=10)
    predict = cluster.fit_predict(df_pca)
    score = silhouette_score(df_pca, predict, random_state=10)
    silhouette.append(score)
    print('For {} clusters the silhouette score is {}'.format(K, score))
# Out:
# For 2 clusters the silhouette score is 0.1401292237427745
# For 3 clusters the silhouette score is 0.10197673215406323
# For 4 clusters the silhouette score is 0.10213224100285742
# For 5 clusters the silhouette score is 0.11632940216476652
# For 6 clusters the silhouette score is 0.12020874933937918

# %%
plt.bar(range(2,7),silhouette)
# Out:
# <BarContainer object of 5 artists>

# %%
for K in n_clusters:
    silhouette_visualizer(KMeans(n_clusters=K, random_state=10), df_pca)

# %%
# The optimal K value is 2

# %% [markdown]
# #### b.	Apply Clustering with optimal value of k and find out if the data points have been clustered correctly using appropriate visualization (8 marks)

# %%
kmean= KMeans(n_clusters=2, random_state=10)
new_df = kmean.fit(df_pca)
df_pca['Cluster']= new_df.labels_

# %%
df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.219779  0.420280  0.161536  1.186096  3.583350  0.672398 -0.521641
# 1  2.950027 -0.840933 -1.515708 -0.609081 -2.554387  2.138962 -0.214763
# 2 -2.329654  2.079524  0.427731 -0.542633  0.384186  0.466972  0.624089
# 3  1.432704 -2.443888 -0.464587 -0.717783 -1.272743  0.585969 -0.191256
# 4 -1.046943  0.212116  0.761675 -0.996764 -0.630342 -0.559103 -0.098364
#
#         PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0  0.475804  0.625970 -1.942639 -0.217646 -0.093702  0.616746 -0.037597
# 1  1.572498  0.218732 -0.055444 -1.190382 -0.737806 -1.050260  0.787866
# 2 -0.981587 -0.061489 -0.841733  0.140871  0.327152 -0.819810 -0.060434
# 3 -0.137589 -2.088605  0.611552 -1.342402  0.387421 -1.666388  0.079376
# 4  1.403242  1.111759  0.815486 -0.205865 -0.083753 -1.288013  0.528981
#
#        PC15      PC16      PC17 Cluster
# 0  0.546347  0.760945 -0.363409       0
# 1  0.681185  0.247451  0.942457       1
# 2 -0.513705  0.244610 -0.156799       0
# 3  0.098201  1.104952  0.447357       1
# 4 -0.385479 -0.281254 -0.505680       0

# %%
df['Cluster']=new_df.labels_
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  Cluster
# 0                      18.0        0
# 1                       6.0        1
# 2                       0.0        0
# 3                       9.0        1
# 4                       0.0        0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### c.	Evaluate the clusters formed using appropriate metrics to support the model built. (6 marks)

# %%
from sklearn.metrics import classification_report, f1_score

# %%
X=df.drop('Cluster', axis=1)
y=df['Cluster']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=10)

# %%
def performance(model, x,y):
    y_pred=model.predict(x)
    print(classification_report(y,y_pred))
    print('F1 score is:', f1_score(y,y_pred))

# %%
rf = RandomForestClassifier(random_state=10)
rf_model = rf.fit(X_train, y_train)

# %%
performance(rf_model, X_train,y_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       434
#            1       1.00      1.00      1.00       367
#
#     accuracy                           1.00       801
#    macro avg       1.00      1.00      1.00       801
# weighted avg       1.00      1.00      1.00       801
#
# F1 score is: 1.0

# %%
performance(rf_model, X_test,y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       198
#            1       0.95      0.94      0.94       146
#
#     accuracy                           0.95       344
#    macro avg       0.95      0.95      0.95       344
# weighted avg       0.95      0.95      0.95       344
#
# F1 score is: 0.9448275862068966

# %% [markdown]
# #### d.Write down a business interpretation/explanation of the model – Use the cluster centroids to make the bussiness inferences for each cluster groups (5 marks)

# %%
df[df['Cluster']==1].mean()
# Out:
# Gender                                 0.475634
# Customer Type                          0.202729
# Age                                   36.284600
# Type of Travel                         0.458090
# Class                                  0.834308
# Flight Distance                      960.405458
# Inflight wifi service                  2.235867
# Departure/Arrival time convenient      2.925926
# Ease of Online booking                 2.423002
# Gate location                          2.890838
# Food and drink                         2.461988
# Online boarding                        2.477583
# Seat comfort                           2.555556
# Inflight entertainment                 2.259259
# On-board service                       2.818713
# Leg room service                       2.732943
# Baggage handling                       3.124756
# Checkin service                        2.978558
# Inflight service                       3.079922
# Cleanliness                            2.399610
# Departure Delay in Minutes            16.945419
# Arrival Delay in Minutes              17.415205
# Cluster                                1.000000
# dtype: float64

# %%
df[df['Cluster']==0].mean()
# Out:
# Gender                                  0.500000
# Customer Type                           0.140823
# Age                                    40.848101
# Type of Travel                          0.188291
# Class                                   0.386076
# Flight Distance                      1406.974684
# Inflight wifi service                   3.139241
# Departure/Arrival time convenient       3.188291
# Ease of Online booking                  3.036392
# Gate location                           2.992089
# Food and drink                          3.848101
# Online boarding                         3.854430
# Seat comfort                            4.128165
# Inflight entertainment                  4.267405
# On-board service                        3.900316
# Leg room service                        3.756329
# Baggage handling                        4.009494
# Checkin service                         3.623418
# Inflight service                        4.112342
# Cleanliness                             3.998418
# Departure Delay in Minutes             14.126582
# Arrival Delay in Minutes               14.042722
# Cluster                                 0.000000
# dtype: float64

# %%
new_df.cluster_centers_
# Out:
# array([[-1.54231736e+00,  1.19673444e-01,  2.29975563e-02,
#          6.08897506e-03,  3.24295462e-02,  2.66047667e-02,
#         -1.42045075e-03,  4.23711803e-02,  3.01327206e-02,
#          1.76038417e-02, -4.14718568e-03,  2.86104133e-03,
#         -1.95799683e-02, -5.98758443e-03,  6.33330492e-03,
#          2.52774888e-02,  6.42039705e-03],
#        [ 1.90008689e+00, -1.47433951e-01, -2.83322720e-02,
#         -7.50142736e-03, -3.99521894e-02, -3.27762428e-02,
#          1.74995102e-03, -5.21999727e-02, -3.71225720e-02,
#         -2.16873839e-02,  5.10920341e-03, -3.52471368e-03,
#          2.41219103e-02,  7.37651727e-03, -7.80243413e-03,
#         -3.11410778e-02, -7.90972892e-03]])

# %%
# Thus we can interpret that the data has 2 clusters and can
